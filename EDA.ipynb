# %% [markdown]
# # EDA (Exploratory data analysis) notebook
#
# Use this notebook to perform exploratory data analysis

# %%
import numpy as np
import pandas as pd

# %%
general_unemployment = pd.read_csv("data/General unemployment by month.csv")
